# %%
#Import Modules
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

#Hide Warning Messages
import warnings
warnings.filterwarnings('ignore')

#Find Current Path & List of Files/Folders in Current Path
current_path = os.getcwd()
current_directory = os.listdir()

#Loop Through List of Files/Folders in Current Path
for item in current_directory:
    
    #Set Condtion for Folder Containing School District Data
    if item.lower().find('treatment') >= 0 and item.lower().find('ipynb') == -1:

        #Loop Through List of Files/Folders in School District Data Folder
        for data in os.listdir(os.path.join(current_path, item)):
            
            #Set Condition for School Data CSV File
            if data.lower().find('mouse') >= 0 and data.lower().find('csv') >= 0:

                #Define Path Variable for School Data CSV File
                mouse_input = os.path.join(current_path, item, data)
                
            #Set Condition for Student Data CSV File
            elif data.lower().find('clinical') >= 0 and data.lower().find('csv') >= 0:

                #Define Path Variable for School Data CSV File
                clinical_input = os.path.join(current_path, item, data)

#Read School & Student CSV Files into Pandas Data Frames
mouse_data = pd.read_csv(mouse_input)
clinical_data = pd.read_csv(clinical_input)

#Merge Mouse & Clinical Data Frames into Combined Data Frame
combined_data = pd.merge(mouse_data, clinical_data, on = 'Mouse ID')

#Display Merged Data Frame
combined_data
# Out:
#      Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        f234  Stelasyn          0           45.000000                 0
# 1        f234  Stelasyn          5           47.313491                 0
# 2        f234  Stelasyn         10           47.904324                 0
# 3        f234  Stelasyn         15           48.735197                 1
# 4        f234  Stelasyn         20           51.112713                 2
# 5        f234  Stelasyn         25           52.178602                 2
# 6        f234  Stelasyn         30           56.873817                 2
# 7        f234  Stelasyn         35           57.748758                 2
# 8        x402  Stelasyn          0           45.000000                 0
# 9        x402  Stelasyn          5           46.327570                 1
# 10       x402  Stelasyn         10           46.886962                 1
# 11       x402  Stelasyn         15           49.119948                 1
# ...

# %% [markdown]
# ## Tumor Response to Treatment

# %%
#Split Combined Data Frame into Groups by Drug Name & Timepoint
drug_time_groups = combined_data.groupby(['Drug', 'Timepoint'])

#Calculate Average Tumor Volume for Grouped Data & Assign To Tumor Average Volume Data Frame
tumor_vol_raw = pd.DataFrame(drug_time_groups.mean().reset_index())

#Drop Metastatic Site Data from Tumor Average Volume Data Frame
tumor_vol_data = tumor_vol_raw.drop('Metastatic Sites', 1)

#Display Average Tumor Volume Data Frame
tumor_vol_data
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0           45.000000
# 1   Capomulin          5           44.266086
# 2   Capomulin         10           43.084291
# 3   Capomulin         15           42.064317
# 4   Capomulin         20           40.716325
# 5   Capomulin         25           39.939528
# 6   Capomulin         30           38.769339
# 7   Capomulin         35           37.816839
# 8   Capomulin         40           36.958001
# 9   Capomulin         45           36.236114
# 10   Ceftamin          0           45.000000
# 11   Ceftamin          5           46.503051
# 12   Ceftamin         10           48.285125
# 13   Ceftamin         15           50.094055
# 14   Ceftamin         20           52.157049
# 15   Ceftamin         25           54.287674
# 16   Ceftamin         30           56.769517
# 17   Ceftamin         35           58.827548
# 18   Ceftamin         40           61.467895
# 19   Ceftamin         45           64.132421
# ...

# %%
#Split Combined Data Frame into Groups by Drug Name & Timepoint
time_drug_groups = combined_data.groupby(['Drug', 'Timepoint'])

#Calculate Standard Error in Tumor Volume for Grouped Data & Assign To Tumor Volume Standard Error Data Frame
tumor_err_raw = pd.DataFrame(time_drug_groups.sem().reset_index())

#Drop Mouse ID & Metastatic Site Data from Tumor Volume Standard Error Data Frame
tumor_err_data = tumor_err_raw.drop(['Mouse ID', 'Metastatic Sites'], 1)

#Display Tumor Volume Standard Error Data Frame
tumor_err_data
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0            0.000000
# 1   Capomulin          5            0.448593
# 2   Capomulin         10            0.702684
# 3   Capomulin         15            0.838617
# 4   Capomulin         20            0.909731
# 5   Capomulin         25            0.881642
# 6   Capomulin         30            0.934460
# 7   Capomulin         35            1.052241
# 8   Capomulin         40            1.223608
# 9   Capomulin         45            1.223977
# 10   Ceftamin          0            0.000000
# 11   Ceftamin          5            0.164505
# 12   Ceftamin         10            0.236144
# 13   Ceftamin         15            0.332053
# 14   Ceftamin         20            0.359482
# 15   Ceftamin         25            0.439356
# 16   Ceftamin         30            0.490620
# 17   Ceftamin         35            0.692248
# 18   Ceftamin         40            0.708505
# 19   Ceftamin         45            0.902358
# ...

# %%
#Reformat Tumor Average Volume Data Frame
tumor_vol_final = tumor_vol_data.pivot(index = 'Timepoint', columns = 'Drug')

#Display Final Tumor Average Volume Data Frame
tumor_vol_final
# Out:
#           Tumor Volume (mm3)                                              \
# Drug               Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol
# Timepoint
# 0                  45.000000  45.000000  45.000000  45.000000  45.000000
# 5                  44.266086  46.503051  47.062001  47.389175  46.796098
# 10                 43.084291  48.285125  49.403909  49.582269  48.694210
# 15                 42.064317  50.094055  51.296397  52.399974  50.933018
# 20                 40.716325  52.157049  53.197691  54.920935  53.644087
# 25                 39.939528  54.287674  55.715252  57.678982  56.731968
# 30                 38.769339  56.769517  58.299397  60.994507  59.559509
# 35                 37.816839  58.827548  60.742461  63.371686  62.685087
# 40                 36.958001  61.467895  63.162824  66.068580  65.600754
# 45                 36.236114  64.132421  65.755562  70.662958  69.265506
#
#
# Drug         Placebo   Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# ...

# %%
#Reformat Tumor Volume Standard Error Data Frame
tumor_err_final = tumor_err_data.pivot(index = 'Timepoint', columns = 'Drug')

#Display Final Tumor Standard Error Data Frame
tumor_err_final
# Out:
#           Tumor Volume (mm3)                                          \
# Drug               Capomulin  Ceftamin Infubinol  Ketapril  Naftisol
# Timepoint
# 0                   0.000000  0.000000  0.000000  0.000000  0.000000
# 5                   0.448593  0.164505  0.235102  0.264819  0.202385
# 10                  0.702684  0.236144  0.282346  0.357421  0.319415
# 15                  0.838617  0.332053  0.357705  0.580268  0.444378
# 20                  0.909731  0.359482  0.476210  0.726484  0.595260
# 25                  0.881642  0.439356  0.550315  0.755413  0.813706
# 30                  0.934460  0.490620  0.631061  0.934121  0.975496
# 35                  1.052241  0.692248  0.984155  1.127867  1.013769
# 40                  1.223608  0.708505  1.055220  1.158449  1.118567
# 45                  1.223977  0.902358  1.144427  1.453186  1.416363
#
#
# Drug        Placebo  Propriva  Ramicane  Stelasyn Zoniferol
# Timepoint
# ...

# %%
#Create & Display Scatter Plot of Tumor Average Volume & Tumor Volume Standard Error Data
plt.errorbar(np.arange(0, 50, 5), tumor_vol_final['Tumor Volume (mm3)']['Capomulin'],
             yerr = tumor_err_final['Tumor Volume (mm3)']['Capomulin'], color = 'red', marker = 'o', linestyle = ':',
             label = 'Capomulin')
plt.errorbar(np.arange(0, 50, 5), tumor_vol_final['Tumor Volume (mm3)']['Infubinol'],
         yerr = tumor_err_final['Tumor Volume (mm3)']['Infubinol'], color = 'blue', marker = '^', linestyle = ':',
         label = 'Infubinol')
plt.errorbar(np.arange(0, 50, 5), tumor_vol_final['Tumor Volume (mm3)']['Ketapril'],
         yerr = tumor_err_final['Tumor Volume (mm3)']['Ketapril'], color = 'green', marker = 's', linestyle = ':',
         label = 'Ketapril')
plt.errorbar(np.arange(0, 50, 5), tumor_vol_final['Tumor Volume (mm3)']['Placebo'],
         yerr = tumor_err_final['Tumor Volume (mm3)']['Placebo'], color = 'black', marker = 'd', linestyle = ':',
         label = 'Placebo')
plt.grid(axis = 'y')
plt.title('Tumor Response to Treatment')
plt.xlabel('Time (Days)')
plt.ylabel('Tumor Volume (mm3)')
plt.legend(loc = 'upper left')
plt.show()

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
#Split Combined Data Frame into Groups by Drug Name & Timepoint
drug_time_groups = combined_data.groupby(['Drug', 'Timepoint'])

#Calculate Average Metastatic Sites for Grouped Data & Assign To Average Metastatic Site Data Frame
met_avg_raw = pd.DataFrame(drug_time_groups.mean().reset_index())

#Drop Tumor Volume Data from Average Metastatic Site Data Frame
met_avg_data = met_avg_raw.drop('Tumor Volume (mm3)', 1)

#Display Average Metastatic Site Data Frame
met_avg_data
# Out:
#          Drug  Timepoint  Metastatic Sites
# 0   Capomulin          0          0.000000
# 1   Capomulin          5          0.160000
# 2   Capomulin         10          0.320000
# 3   Capomulin         15          0.375000
# 4   Capomulin         20          0.652174
# 5   Capomulin         25          0.818182
# 6   Capomulin         30          1.090909
# 7   Capomulin         35          1.181818
# 8   Capomulin         40          1.380952
# 9   Capomulin         45          1.476190
# 10   Ceftamin          0          0.000000
# 11   Ceftamin          5          0.380952
# 12   Ceftamin         10          0.600000
# 13   Ceftamin         15          0.789474
# 14   Ceftamin         20          1.111111
# 15   Ceftamin         25          1.500000
# 16   Ceftamin         30          1.937500
# 17   Ceftamin         35          2.071429
# 18   Ceftamin         40          2.357143
# 19   Ceftamin         45          2.692308
# 20  Infubinol          0          0.000000
# ...

# %%
#Split Combined Data Frame into Groups by Drug Name & Timepoint
time_drug_groups = combined_data.groupby(['Drug', 'Timepoint'])

#Calculate Standard Error in Metastatic Site Count for Grouped Data & Assign To Metastatic Site Standard Error Data Frame
met_err_raw = pd.DataFrame(time_drug_groups.sem().reset_index())

#Drop Mouse ID & Tumor Volume Data from Metastatic Site Standard Error Data Frame
met_err_data = met_err_raw.drop(['Mouse ID', 'Tumor Volume (mm3)'], 1)

#Display Metastatic Site Standard Error Data Frame
met_err_data
# Out:
#          Drug  Timepoint  Metastatic Sites
# 0   Capomulin          0          0.000000
# 1   Capomulin          5          0.074833
# 2   Capomulin         10          0.125433
# 3   Capomulin         15          0.132048
# 4   Capomulin         20          0.161621
# 5   Capomulin         25          0.181818
# 6   Capomulin         30          0.172944
# 7   Capomulin         35          0.169496
# 8   Capomulin         40          0.175610
# 9   Capomulin         45          0.202591
# 10   Ceftamin          0          0.000000
# 11   Ceftamin          5          0.108588
# 12   Ceftamin         10          0.152177
# 13   Ceftamin         15          0.180625
# 14   Ceftamin         20          0.241034
# 15   Ceftamin         25          0.258831
# 16   Ceftamin         30          0.249479
# 17   Ceftamin         35          0.266526
# 18   Ceftamin         40          0.289128
# 19   Ceftamin         45          0.286101
# 20  Infubinol          0          0.000000
# ...

# %%
#Reformat Average Metastatic Site Data Frame
met_avg_final = met_avg_data.pivot(index = 'Timepoint', columns = 'Drug')

#Display Final Average Metastatic Site Data Frame
met_avg_final
# Out:
#           Metastatic Sites                                                    \
# Drug             Capomulin  Ceftamin Infubinol  Ketapril  Naftisol   Placebo
# Timepoint
# 0                 0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5                 0.160000  0.380952  0.280000  0.304348  0.260870  0.375000
# 10                0.320000  0.600000  0.666667  0.590909  0.523810  0.833333
# 15                0.375000  0.789474  0.904762  0.842105  0.857143  1.250000
# 20                0.652174  1.111111  1.050000  1.210526  1.150000  1.526316
# 25                0.818182  1.500000  1.277778  1.631579  1.500000  1.941176
# 30                1.090909  1.937500  1.588235  2.055556  2.066667  2.266667
# 35                1.181818  2.071429  1.666667  2.294118  2.266667  2.642857
# 40                1.380952  2.357143  2.100000  2.733333  2.466667  3.166667
# 45                1.476190  2.692308  2.111111  3.363636  2.538462  3.272727
#
#
# ...

# %%
#Reformat Metastatic Site Standard Error Data Frame
met_err_final = met_err_data.pivot(index = 'Timepoint', columns = 'Drug')

#Display Final Metastatic Site Standard Error Data Frame
met_err_final
# Out:
#           Metastatic Sites                                                    \
# Drug             Capomulin  Ceftamin Infubinol  Ketapril  Naftisol   Placebo
# Timepoint
# 0                 0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5                 0.074833  0.108588  0.091652  0.098100  0.093618  0.100947
# 10                0.125433  0.152177  0.159364  0.142018  0.163577  0.115261
# 15                0.132048  0.180625  0.194015  0.191381  0.158651  0.190221
# 20                0.161621  0.241034  0.234801  0.236680  0.181731  0.234064
# 25                0.181818  0.258831  0.265753  0.288275  0.185240  0.263888
# 30                0.172944  0.249479  0.227823  0.347467  0.266667  0.300264
# 35                0.169496  0.266526  0.224733  0.361418  0.330464  0.341412
# 40                0.175610  0.289128  0.314466  0.315725  0.321702  0.297294
# 45                0.202591  0.286101  0.309320  0.278722  0.351104  0.304240
#
#
# ...

# %%
#Create & Display Scatter Plot of Average Metastatic Site Count & Metastatic Site Standard Error Data
plt.errorbar(np.arange(0, 50, 5), met_avg_final['Metastatic Sites']['Capomulin'],
             yerr = met_err_final['Metastatic Sites']['Capomulin'], color = 'red', marker = 'o', linestyle = ':',
             label = 'Capomulin')
plt.errorbar(np.arange(0, 50, 5), met_avg_final['Metastatic Sites']['Infubinol'],
         yerr = met_err_final['Metastatic Sites']['Infubinol'], color = 'blue', marker = '^', linestyle = ':',
         label = 'Infubinol')
plt.errorbar(np.arange(0, 50, 5), met_avg_final['Metastatic Sites']['Ketapril'],
         yerr = met_err_final['Metastatic Sites']['Ketapril'], color = 'green', marker = 's', linestyle = ':',
         label = 'Ketapril')
plt.errorbar(np.arange(0, 50, 5), met_avg_final['Metastatic Sites']['Placebo'],
         yerr = met_err_final['Metastatic Sites']['Placebo'], color = 'black', marker = 'd', linestyle = ':',
         label = 'Placebo')
plt.grid(axis = 'y')
plt.title('Metastatic Spread During Treatment')
plt.xlabel('Time (Days)')
plt.ylabel('Metastatic Sites')
plt.legend(loc = 'upper left')
plt.show()

# %% [markdown]
# ## Survival Rates

# %%
#Split Combined Data Frame into Groups by Drug Name & Timepoint
drug_time_groups = combined_data.groupby(['Drug', 'Timepoint'])

#Calculate Number of Live Mice for Grouped Data & Assign To Mice Count Data Frame
mice_count_raw = pd.DataFrame(drug_time_groups.count().reset_index())

#Drop Metastatic Site Data from Tumor Average Volume Data Frame
mice_count_data = mice_count_raw.drop(['Tumor Volume (mm3)', 'Metastatic Sites'], 1)

#Rename Mouse ID Column to Mouse Count
mice_count_data = mice_count_data.rename(columns = {'Mouse ID': 'Mouse Count'})

#Display Average Tumor Volume Data Frame
mice_count_data
# Out:
#          Drug  Timepoint  Mouse Count
# 0   Capomulin          0           25
# 1   Capomulin          5           25
# 2   Capomulin         10           25
# 3   Capomulin         15           24
# 4   Capomulin         20           23
# 5   Capomulin         25           22
# 6   Capomulin         30           22
# 7   Capomulin         35           22
# 8   Capomulin         40           21
# 9   Capomulin         45           21
# 10   Ceftamin          0           25
# 11   Ceftamin          5           21
# 12   Ceftamin         10           20
# 13   Ceftamin         15           19
# 14   Ceftamin         20           18
# 15   Ceftamin         25           18
# 16   Ceftamin         30           16
# 17   Ceftamin         35           14
# 18   Ceftamin         40           14
# 19   Ceftamin         45           13
# 20  Infubinol          0           25
# 21  Infubinol          5           25
# 22  Infubinol         10           21
# 23  Infubinol         15           21
# ...

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview the Data Frame

# %%
# Generate the Plot (Accounting for percentages)

# Save the Figure

# Show the Figure
plt.show()

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug

# Display the data to confirm

# %%
# Store all Relevant Percent Changes into a Tuple


# Splice the data between passing and failing drugs


# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-eb553307bee3> in <module>
#      18
#      19 # Show the Figure
# ---> 20 fig.show()
#
# NameError: name 'fig' is not defined
